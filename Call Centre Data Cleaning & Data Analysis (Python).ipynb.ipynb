# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
calls = pd.read_excel("Call Centre Data.xlsx")

# %%
calls.head()
# Out:
#                          Id Call Timestamp Call Centre City      Channel  \
# 0  DKK-57076809-W-055481-FU     2020-10-29      Los Angeles  Call-Center
# 1  QGK-72219678-W-102139-KY     2020-10-05        Baltimore      Chatbot
# 2  GYJ-30025932-A-023015-LD     2020-10-04      Los Angeles  Call-Center
# 3  ZJI-96807559-I-620008-M7     2020-10-17      Los Angeles      Chatbot
# 4  DDU-69451719-O-176482-FM     2020-10-17      Los Angeles  Call-Center
#
#           City       Customer Name            Reason Response Time  \
# 0      Detroit    Analise Gairdner  Billing Question    Within SLA
# 1  Spartanburg    Crichton Kidsley    Service Outage    Within SLA
# 2  Gainesville   Averill Brundrett  Billing Question     Above SLA
# 3     Portland     Noreen Lafflina  Billing Question    Within SLA
# 4   Fort Wayne  Toma Van der Beken          Payments    Within SLA
#
#        Sentiment           State  Call Duration (Mins)  CSAT Score
# ...
